# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# 加载数据
with open('../../data/supplementary_figures/slr_res/DIVA_data/Coast_with_Mang_TOP10pct.pkl', 'rb') as f:
    data = pickle.load(f)

# 选择Pop5和恢复策略50%
area_after_SLR_126_1 = data['area_after_SLR_126'][:, 1]
area_after_SLR_585_1 = data['area_after_SLR_585'][:, 1]
area_restoration_126_1 = data['area_restoration_126'][:, 0]
area_restoration_585_1 = data['area_restoration_585'][:, 0]

# 提取agb和area数据
agb_present = data['agb_present']
agb_grow = data['agb_grow']
agb_126 = data['agb_126']
agb_585 = data['agb_585']
area = data['area']

# 计算各类总AGB
total_agb_present = np.nansum(agb_present * area) / (10 ** 9)
total_agb_grow = np.nansum(agb_grow * area) / (10 ** 9)
total_agb_126 = np.nansum(agb_126 * area) / (10 ** 9)
total_agb_585 = np.nansum(agb_585 * area) / (10 ** 9)

total_agb_126_restoration = np.nansum(agb_126 * (area + area_restoration_126_1)) / (10 ** 9)
total_agb_585_restoration = np.nansum(agb_585 * (area + area_restoration_585_1)) / (10 ** 9)
total_agb_126_restoration_SLR = np.nansum(agb_126 * (area_after_SLR_126_1 + area_restoration_126_1)) / (10 ** 9)
total_agb_585_restoration_SLR = np.nansum(agb_585 * (area_after_SLR_585_1 + area_restoration_585_1)) / (10 ** 9)

# Set global font to Helvetica
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = 16
# Set the mathtext font to Helvetica
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Helvetica'
plt.rcParams['mathtext.it'] = 'Helvetica:italic'
plt.rcParams['mathtext.bf'] = 'Helvetica:bold'


# 绘制图形
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
fig.text(0, 0.5, 'Total AGB (Pg DM)', va='center', rotation='vertical', fontsize=18)
ax1, ax2, ax3, ax4 = axes.flatten()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# 第一张图：低温化情境
xtips = np.arange(1, 7)
ytips = [(total_agb_present + 1) / 2, total_agb_grow, total_agb_126, total_agb_126_restoration, total_agb_126_restoration_SLR, (total_agb_126_restoration_SLR + 1) / 2]
labels = [f"{total_agb_present:.2f}",
          f"{total_agb_grow - total_agb_present:+.2f}",
          f"{total_agb_126 - total_agb_grow:+.2f}",
          f"{total_agb_126_restoration - total_agb_126:+.2f}",
          f"{total_agb_126_restoration_SLR-total_agb_126_restoration:+.2f}",
          f"{total_agb_126_restoration_SLR:.2f}"]

bars = [
    ax1.bar(1, total_agb_present, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none'),
    ax1.bar(2, total_agb_grow, color=(118 / 255, 215 / 255, 196 / 255), edgecolor='none', label='Potential growth to maturity'),
    ax1.bar(2, total_agb_present, color='w', edgecolor='w'),
    ax1.bar(3, total_agb_126, color=(243 / 255, 182 / 255, 177 / 255), edgecolor='none', label='Climate and hydrology'),
    ax1.bar(3, total_agb_grow, color='w', edgecolor='w'),
    ax1.bar(4, total_agb_126_restoration, color=(235 / 255, 222 / 255, 247 / 255), edgecolor='none', label='Restoration'),
    ax1.bar(4, total_agb_126, color='w', edgecolor='w'),
    ax1.bar(5, total_agb_126_restoration, color=(174 / 255, 214 / 255, 241 / 255), edgecolor='none', label='Sea-level rise'),
    ax1.bar(5, total_agb_126_restoration_SLR, color='w', edgecolor='none'),
    ax1.bar(6, total_agb_126_restoration_SLR, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none')
]

# 设置每个矩形对象的边框颜色
for bar in bars:
    for rect in bar.get_children():
        rect.set_edgecolor('none')

# 添加文本标签
for i, (xtip, ytip, label) in enumerate(zip(xtips, ytips, labels)):
    label_value = float(label)
    if label_value > 0:
        ax1.text(xtip, ytip, label, ha='center', va='bottom')
    else:
        ax1.text(xtip, ytip - 0.01, label, ha='center', va='top')

# 第二张图：高温化情境
xtips = np.arange(1, 7)
ytips = [(total_agb_present + 1) / 2, total_agb_grow, total_agb_585, total_agb_585_restoration, total_agb_585_restoration_SLR, (total_agb_585_restoration_SLR + 1) / 2]
labels = [f"{total_agb_present:.2f}",
          f"{total_agb_grow - total_agb_present:+.2f}",
          f"{total_agb_585 - total_agb_grow:+.2f}",
          f"{total_agb_585_restoration - total_agb_585:+.2f}",
          f"{total_agb_585_restoration_SLR-total_agb_585_restoration:+.2f}",
          f"{total_agb_585_restoration_SLR:.2f}"]

bars = [
    ax2.bar(1, total_agb_present, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none'),
    ax2.bar(2, total_agb_grow, color=(118 / 255, 215 / 255, 196 / 255), edgecolor='none', label='Growth'),
    ax2.bar(2, total_agb_present, color='w', edgecolor='w'),
    ax2.bar(3, total_agb_585, color=(243 / 255, 182 / 255, 177 / 255), edgecolor='none', label='Climate and hydrology'),
    ax2.bar(3, total_agb_grow, color='w', edgecolor='w'),
    ax2.bar(4, total_agb_585_restoration, color=(235 / 255, 222 / 255, 247 / 255), edgecolor='none', label='Restoration'),
    ax2.bar(4, total_agb_585, color='w', edgecolor='w'),
    ax2.bar(5, total_agb_585_restoration, color=(174 / 255, 214 / 255, 241 / 255), edgecolor='none', label='Sea-level rise'),
    ax2.bar(5, total_agb_585_restoration_SLR, color='w', edgecolor='none'),
    ax2.bar(6, total_agb_585_restoration_SLR, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none')
]

# 设置每个矩形对象的边框颜色
for bar in bars:
    for rect in bar.get_children():
        rect.set_edgecolor('none')

# 添加文本标签
for i, (xtip, ytip, label) in enumerate(zip(xtips, ytips, labels)):
    label_value = float(label)
    if label_value > 0:
        ax2.text(xtip, ytip, label, ha='center', va='bottom')
    else:
        ax2.text(xtip, ytip - 0.01, label, ha='center', va='top')

labels = [f"{total_agb_present:.5}",
          f"{total_agb_grow - total_agb_present:+.5f}",
          f"{total_agb_126 - total_agb_grow:+.5f}",
          f"{total_agb_126_restoration - total_agb_126:+.5f}",
          f"{total_agb_126_restoration_SLR-total_agb_126_restoration:+.5f}",
          f"{total_agb_126_restoration_SLR:.5f}"]

labels = [f"{total_agb_present:.5f}",
          f"{total_agb_grow - total_agb_present:+.5f}",
          f"{total_agb_585 - total_agb_grow:+.5f}",
          f"{total_agb_585_restoration - total_agb_585:+.5f}",
          f"{total_agb_585_restoration_SLR-total_agb_585_restoration:+.5f}",
          f"{total_agb_585_restoration_SLR:.5f}"]



# 加载数据
with open('../../data/supplementary_figures/slr_res/DIVA_data/Coast_with_Mang_TOP30pct.pkl', 'rb') as f:
    data = pickle.load(f)

# 选择Pop5和恢复策略50%
area_after_SLR_126_1 = data['area_after_SLR_126'][:, 1]
area_after_SLR_585_1 = data['area_after_SLR_585'][:, 1]
area_restoration_126_1 = data['area_restoration_126'][:, 0]
area_restoration_585_1 = data['area_restoration_585'][:, 0]

# 提取agb和area数据
agb_present = data['agb_present']
agb_grow = data['agb_grow']
agb_126 = data['agb_126']
agb_585 = data['agb_585']
area = data['area']

# 计算各类总AGB
total_agb_present = np.nansum(agb_present * area) / (10 ** 9)
total_agb_grow = np.nansum(agb_grow * area) / (10 ** 9)
total_agb_126 = np.nansum(agb_126 * area) / (10 ** 9)
total_agb_585 = np.nansum(agb_585 * area) / (10 ** 9)

total_agb_126_restoration = np.nansum(agb_126 * (area + area_restoration_126_1)) / (10 ** 9)
total_agb_585_restoration = np.nansum(agb_585 * (area + area_restoration_585_1)) / (10 ** 9)
total_agb_126_restoration_SLR = np.nansum(agb_126 * (area_after_SLR_126_1 + area_restoration_126_1)) / (10 ** 9)
total_agb_585_restoration_SLR = np.nansum(agb_585 * (area_after_SLR_585_1 + area_restoration_585_1)) / (10 ** 9)

# 第三张图：低温化情境
xtips = np.arange(1, 7)
ytips = [(total_agb_present + 1) / 2, total_agb_grow, total_agb_126, total_agb_126_restoration, total_agb_126_restoration_SLR, (total_agb_126_restoration_SLR + 1) / 2]
labels = [f"{total_agb_present:.2f}",
          f"{total_agb_grow - total_agb_present:+.2f}",
          f"{total_agb_126 - total_agb_grow:+.2f}",
          f"{total_agb_126_restoration - total_agb_126:+.2f}",
          f"{total_agb_126_restoration_SLR-total_agb_126_restoration:+.2f}",
          f"{total_agb_126_restoration_SLR:.2f}"]

bars = [
    ax3.bar(1, total_agb_present, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none'),
    ax3.bar(2, total_agb_grow, color=(118 / 255, 215 / 255, 196 / 255), edgecolor='none', label='Potential growth to maturity'),
    ax3.bar(2, total_agb_present, color='w', edgecolor='w'),
    ax3.bar(3, total_agb_126, color=(243 / 255, 182 / 255, 177 / 255), edgecolor='none', label='Climate and hydrology'),
    ax3.bar(3, total_agb_grow, color='w', edgecolor='w'),
    ax3.bar(4, total_agb_126_restoration, color=(235 / 255, 222 / 255, 247 / 255), edgecolor='none', label='Restoration'),
    ax3.bar(4, total_agb_126, color='w', edgecolor='w'),
    ax3.bar(5, total_agb_126_restoration, color=(174 / 255, 214 / 255, 241 / 255), edgecolor='none', label='Sea-level rise'),
    ax3.bar(5, total_agb_126_restoration_SLR, color='w', edgecolor='none'),
    ax3.bar(6, total_agb_126_restoration_SLR, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none')
]

# 设置每个矩形对象的边框颜色
for bar in bars:
    for rect in bar.get_children():
        rect.set_edgecolor('none')

# 添加文本标签
for i, (xtip, ytip, label) in enumerate(zip(xtips, ytips, labels)):
    label_value = float(label)
    if label_value > 0:
        ax3.text(xtip, ytip, label, ha='center', va='bottom')
    else:
        ax3.text(xtip, ytip - 0.01, label, ha='center', va='top')

# 第二张图：高温化情境
xtips = np.arange(1, 7)
ytips = [(total_agb_present + 1) / 2, total_agb_grow, total_agb_585, total_agb_585_restoration, total_agb_585_restoration_SLR, (total_agb_585_restoration_SLR + 1) / 2]
labels = [f"{total_agb_present:.2f}",
          f"{total_agb_grow - total_agb_present:+.2f}",
          f"{total_agb_585 - total_agb_grow:+.2f}",
          f"{total_agb_585_restoration - total_agb_585:+.2f}",
          f"{total_agb_585_restoration_SLR-total_agb_585_restoration:+.2f}",
          f"{total_agb_585_restoration_SLR:.2f}"]

bars = [
    ax4.bar(1, total_agb_present, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none'),
    ax4.bar(2, total_agb_grow, color=(118 / 255, 215 / 255, 196 / 255), edgecolor='none', label='Growth'),
    ax4.bar(2, total_agb_present, color='w', edgecolor='w'),
    ax4.bar(3, total_agb_585, color=(243 / 255, 182 / 255, 177 / 255), edgecolor='none', label='Climate and hydrology'),
    ax4.bar(3, total_agb_grow, color='w', edgecolor='w'),
    ax4.bar(4, total_agb_585_restoration, color=(235 / 255, 222 / 255, 247 / 255), edgecolor='none', label='Restoration'),
    ax4.bar(4, total_agb_585, color='w', edgecolor='w'),
    ax4.bar(5, total_agb_585_restoration, color=(174 / 255, 214 / 255, 241 / 255), edgecolor='none', label='Sea-level rise'),
    ax4.bar(5, total_agb_585_restoration_SLR, color='w', edgecolor='none'),
    ax4.bar(6, total_agb_585_restoration_SLR, color=(204 / 255, 204 / 255, 204 / 255), edgecolor='none')
]

# 设置每个矩形对象的边框颜色
for bar in bars:
    for rect in bar.get_children():
        rect.set_edgecolor('none')

# 添加文本标签
for i, (xtip, ytip, label) in enumerate(zip(xtips, ytips, labels)):
    label_value = float(label)
    if label_value > 0:
        ax4.text(xtip, ytip, label, ha='center', va='bottom')
    else:
        ax4.text(xtip, ytip - 0.01, label, ha='center', va='top')

# 设置图形属性
for ax in [ax1, ax2, ax3, ax4]:
    ax.set_xlim([0, 7])
    ax.set_ylim([1.0, 2.5])
    ax.set_yticks(np.arange(1.0, 2.6, 0.5))
    ax.set_xticks([1, 6])
    ax.set_xticklabels(['Present-day', '2100'])
    # ax.set_ylabel('Total AGB (Pg DM)')
    ax.tick_params(axis='both')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

# ax1.set_ylabel(' ')

# 添加图例
ax1.set_title("Low-Warming\n$\mathbf{{a}}$", loc='left')
ax2.set_title("High-Warming\n$\mathbf{{b}}$", loc='left')
ax3.set_title('c', loc='left', fontweight='bold')
ax4.set_title('d', loc='left', fontweight='bold')

# 获取所有图例句柄和标签
handles, labels = ax1.get_legend_handles_labels()
# ax1.legend(handles, labels, loc='lower center', frameon=False)
ax1.legend(handles, labels, loc='lower center', frameon=False, handlelength=0.8, fontsize=16, handletextpad=0.3)
# # 获取所有图例句柄和标签
# handles, labels = ax2.get_legend_handles_labels()
# ax2.legend(handles, labels, loc='lower center', frameon=False)
# handles, labels = ax3.get_legend_handles_labels()
# ax3.legend(handles, labels, loc='lower center', frameon=False)
# handles, labels = ax4.get_legend_handles_labels()
# ax4.legend(handles, labels, loc='lower center', frameon=False)

ax2_right = ax2.twinx()
ax2_right.set_ylabel('Define "target potential height\n distribution" with top 10% sub-grids', rotation=270, color='k', fontsize=18, labelpad=20)
ax2_right.set_yticks([])
ax2_right.spines['right'].set_visible(False)
ax2_right.spines['top'].set_visible(False)
ax2_right.spines['left'].set_visible(False)
ax2_right.spines['bottom'].set_visible(False)

ax4_right = ax4.twinx()
ax4_right.set_ylabel('Define "target potential height\n distribution" with top 30% sub-grids', rotation=270, color='k', fontsize=18, labelpad=20)
ax4_right.set_yticks([])
ax4_right.spines['right'].set_visible(False)
ax4_right.spines['top'].set_visible(False)
ax4_right.spines['left'].set_visible(False)
ax4_right.spines['bottom'].set_visible(False)

# 保存图像
plt.tight_layout()
plt.savefig('../../figures/supplementary/figS20_potential_height_thresholds.png', dpi=400)
plt.show()
